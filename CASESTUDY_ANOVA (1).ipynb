# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'D:\Devi\ICT_TVM\CASE STUDY\Sales_data_zone_wise.csv')
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
data.isnull().sum()
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %% [markdown]
# There is no null values are present in the given data set

# %% [markdown]
# ### ● The mean sales generated by each zone.

# %%
z_a=data['Zone - A'].mean()
z_b=data['Zone - B'].mean()
z_c=data['Zone - C'].mean()
z_d=data['Zone - D'].mean()

df=pd.DataFrame({'Zone-A':[z_a],'Zone-B':[z_b],'Zone-C':[z_c],'Zone-D':[z_d]})

# %%
df
# Out:
#          Zone-A        Zone-B        Zone-C        Zone-D
# 0  1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06

# %%
df.plot(kind='bar',title="Mean Sales by each zone")
# Out:
# <AxesSubplot:title={'center':'Mean Sales by each zone'}>

# %% [markdown]
# The graph shows the average sales in each of the 4 zones. Zone D has the highest sale

# %% [markdown]
# ### Total sales generated by all the zones for each month

# %%
data['Sum']=data['Zone - A']+data['Zone - B']+data['Zone - C']+data['Zone - D']
data.head(5)
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D      Sum
# 0  Month - 1   1483525   1748451   1523308   2267260  7022544
# 1  Month - 2   1238428   1707421   2212113   1994341  7152303
# 2  Month - 3   1860771   2091194   1282374   1241600  6475939
# 3  Month - 4   1871571   1759617   2290580   2252681  8174449
# 4  Month - 5   1244922   1606010   1818334   1326062  5995328

# %%
data[['Month','Sum']].plot(kind='bar',figsize=(10,10),title="MONTHLY SALES",color='green')
# Out:
# <AxesSubplot:title={'center':'MONTHLY SALES'}>

# %% [markdown]
# The graph shows the deviation in sum of sales done by each zones in every month. From the graph we can say that, sales is very much high in month 4 comparing to other monthly sales

# %% [markdown]
# ### ● Check whether all the zones generate the same amount of sales.

# %% [markdown]
# All zones are independant of each others,so that we can perfrom ANOVA test

# %% [markdown]
# Setting Hypothesis

# %% [markdown]
# H0: All zones generates the same amount of sales

# %% [markdown]
# H1: All zones generate different amount of sales

# %%
from scipy.stats import f_oneway
from scipy import stats

# %%
F, p = stats.f_oneway(data['Zone - A'], data['Zone - B'],data['Zone - C'],data['Zone - D'])

# %%
alpha=.05
print("p value :", p)
if p < alpha:
    print("Reject H0")
else:
    print("Fail to reject H0.")
# Out:
# p value : 0.0011827601694503335
# Reject H0

# %% [markdown]
# The p value is less than alpha so that we can reject the null hypothesis and accept the alternative hypothesis ie all zones generete different amount of sales
